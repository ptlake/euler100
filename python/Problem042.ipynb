# %% [markdown]
# # Problem 042:  Coded Triangle Numbers

# %% [markdown]
# > The $n$th term of the sequence of triangle numbers is given by, $t_n = \frac12n(n+1)$; so the first ten triangle numbers are:
# >
# > $$1, 3, 6, 10, 15, 21, 28, 36, 45, 55, \dots$$
# >
# > By converting each letter in a word to a number corresponding to its alphabetical position and adding these values we form a word value. For example, the word value for SKY is $19 + 11 + 25 = 55 = t_{10}$. If the word value is a triangle number then we shall call the word a triangle word.
# >
# > Using words.txt (right click and 'Save Link/Target As...'), a 16K text file containing nearly two-thousand common English words, how many are triangle words?

# %% [markdown]
# ## Solution $\mathcal O(N)$

# %% [markdown]
# A lot of this problem is the same as Problem 022, namely in the handling of the input and the conversion of the `string` to a value.
#
# From there, the largest value is found in the resulting list and the triangle numbers are generated up to that maximum value.  This collection of triangle numbers are cast into a `set` for quick access for the `in` operator.
#
# The time scaling will be $\mathcal O(N)$ where $N$ is the total number of characters in all the words due to the summation over all letter values.

# %%
# %%time

def triangle_up_to(N: int) -> int:
    tri = 1
    i = 1
    while tri <= N:
        yield tri
        i += 1
        tri += i


def p042(words: list[str]) -> int:
    s = [sum(map(ord, wnow)) - 64 * len(wnow) for wnow in words]
    smax = max(s)
    tri = set(n for n in triangle_up_to(smax))
    return len([1 for x in s if x in tri])
        
with open("../data/p042_words.txt", 'r') as f:
    words = f.read().split("\",\"")
words[0] = words[0][1:]
words[-1] = words[-1][:-1]

ans = p042(words)

print(ans)
# Out:
# 162
# CPU times: user 4.13 ms, sys: 846 μs, total: 4.97 ms
# Wall time: 4.31 ms
